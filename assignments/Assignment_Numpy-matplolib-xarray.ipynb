# %% [markdown]
# # Assignment: Numpy, matplolib, and xarray
# The goal of this assignment is to gain comfort creating, visualizating, and computing with numpy array, matplolib and xarray!

# %% [markdown]
# ### Part I: Creating and Manipulating Arrays

# %% [markdown]
# 1. First import numpy, matplotlib libraries

# %% [markdown]
# 2. Create two 2D arrays representing coordinates x, y on the cartesian plan. Both should cover the range (-2, 2) and have 100 points in each direction.

# %% [markdown]
# 3. Visualize each 2D array using pcolormesh. **Hint:** use the [meshgrid](https://numpy.org/doc/stable/reference/generated/numpy.meshgrid.html).

# %% [markdown]
# ### Part II: Plotting and analyzing [ARGO](https://argo.ucsd.edu/) float data
#
# In this problem, we use real data from ocean profiling floats. ARGO floats are autonomous robotic instruments that collect Temperature, Salinity, and Pressure data from the ocean. ARGO floats collect one “profile” (a set of messurements at different depths or “levels”). Each profile has a single latitude, longitude, and date associated with it, in addition to many different levels.
#
# **How do floats work** (https://argo.ucsd.edu/how-do-floats-work/)
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. First import numpy, matplotlib and xarray libraries

# %%
# write your code here

# %% [markdown]
# 2. Find in the 'data' directory an example ARGO float profile from the North Atlantic (**nodc_3901598_prof.nc**).
# Load the data file using xarray and explore its content. **Info:** Argo uses the dimensions n_levels (for depth) and n_prof (for time).

# %%
# write your code here

# %% [markdown]
# 3. Create Quick Timeseries Profile plot of Temperature. Try to have 'n_prof' on the x-axis and 'n_levels' on the y-axis with depth increasing downwards. **Note,** when possible, you should use the <code>_adjusted</code> variables, as those have been corrected.

# %%
# write your code here

# %% [markdown]
# 4. Create a profile plot of a single profile.

# %%
# write your code here

# %% [markdown]
# 5. Make a 1 x 3 array of plots for each column of data in Temperature, Salinity and Pressure (three plots).
#
# The vertical scale should be the levels data. Flip the veritcal axis direction so that levels increase downward on the plot. Each plot should have a line for each column of data. Make sure you label the axes and put a title on each subplot.

# %%
# write your code here

# %% [markdown]
# 6. Compute the mean and standard deviation of each of Temperature, Salinity and Pressure at each depth in level.

# %%
# write your code here

# %% [markdown]
# 7. Now make three similar plot, but show only the mean Temperature, Salinity and Pressure at each depth. Show [error bars](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.errorbar.html) on each plot using the standard deviations

# %%
# write your code here

# %% [markdown]
# 8. Create a [T-S Diagram](https://en.wikipedia.org/wiki/Temperature%E2%80%93salinity_diagram) for a single profile. **Hint:** it is just a scatterplot of temp and salinity. Also,  use a colored scatterplot to show the depth dimension.

# %%
# write your code here

# %% [markdown]
# 8. [**bonus**] Try to plot in the density contours in the T-S Diagram. **Hint:** To calculate density, we will need the wonderful [seawater](https://pythonhosted.org/seawater/index.html) library. Check also this [Ocean Python T-S Diagram](https://oceanpython.org/2013/02/17/t-s-diagram/) example.

# %%
# write your code here

# %% [markdown]
# 9. Create a scatter plot of the lon, lat positions of the ARGO float. **Hint:** Use the [plt.scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) function.

# %%
# write your code here

# %% [markdown]
# 10. Try to make the float track map with Cartopy! Try to color the positions by the date.

# %%
# write your code here
